# %% [markdown]
# ### Drug Repurposing Data Processing
#
# **Objective:** This code is designed to process drug repurposing data by applying specific filtering criteria to the results. It also retrieves additional information, such as PubChem CID and SMILES notation, which can be used for further analysis and input into SwissADME.
#
# ---
#
# ### Step 1: Filtering Drug Repurposing Results
#
# - **Input:** `export.csv`
#
# - **Output:** Four distinct CSV files:
#   - `filtered_cp_above_90.csv`: Contains filtered data for drug type 'cp' with scores exceeding 90.
#   - `filtered_kd_above_90.csv`: Contains filtered data for drug type 'kd' with scores exceeding 90.
#   - `filtered_oe_above_90.csv`: Contains filtered data for drug type 'oe' with scores exceeding 90.
#   - `filtered_cc_above_90.csv`: Contains filtered data for drug type 'cc' with scores exceeding 90.

# %%
import pandas as pd
from IPython.display import display

# Step 1: Filtering Drug Repurposing Results
# Input: export.csv
# Output: Four separate CSV files for types 'cp', 'kd', 'oe', 'cc' with scores above 90

data = pd.read_csv('export.csv')
print("Contents of export.csv:")
display(data)
# Out:
# Contents of export.csv:
#       Rank  Score Type                  ID         Name  \
# 0        1  99.98   oe  ccsbBroad304_01966       RUVBL1
# 1        2  99.98   kd         CGS001-8848      TSC22D1
# 2        3  99.96   oe  ccsbBroad304_00841        IKBKB
# 3        4  99.94   kd         CGS001-1196         CLK2
# 4        5  99.88   cp       BRD-A02333338  cyclopamine
# ...    ...    ...  ...                 ...          ...
# 8023  8024 -99.95   kd        CGS001-64786      TBC1D15
# 8024  8025 -99.96   oe  ccsbBroad304_07172       ZNF195
# 8025  8026 -99.96   cp       BRD-K17306061   aprepitant
# 8026  8027 -99.98   kd         CGS001-9326       ZNHIT3
# 8027  8028 -99.98   kd         CGS001-3215        HOXB5
#
#                                   Description
# 0                          ATPases / AAA-type
# 1                                           -
# 2                                  IKK family
# 3                            CDC-like kinases
# 4              Smoothened receptor antagonist
# ...                                       ...
# 8023                                        -
# 8024                  Zinc fingers, C2H2-type
# 8025                    Tachykinin antagonist
# 8026                   Zinc fingers, HIT-type
# 8027  Homeoboxes / ANTP class : HOXL subclass
#
# [8028 rows x 6 columns]

# %%
# Filtering rows based on Type and Score > 90
filtered_cp = data[(data['Type'] == 'cp') & (data['Score'] > 90)]
filtered_kd = data[(data['Type'] == 'kd') & (data['Score'] > 90)]
filtered_oe = data[(data['Type'] == 'oe') & (data['Score'] > 90)]
filtered_cc = data[(data['Type'] == 'cc') & (data['Score'] > 90)]

# %%
# Saving filtered data to new CSV files
filtered_cp.to_csv('filtered_cp_above_90.csv', index=False)
filtered_kd.to_csv('filtered_kd_above_90.csv', index=False)
filtered_oe.to_csv('filtered_oe_above_90.csv', index=False)
filtered_cc.to_csv('filtered_cc_above_90.csv', index=False)

# %%
# Load and display CSV files
filtered_cp = pd.read_csv('filtered_cp_above_90.csv')
filtered_kd = pd.read_csv('filtered_kd_above_90.csv')
filtered_oe = pd.read_csv('filtered_oe_above_90.csv')
filtered_cc = pd.read_csv('filtered_cc_above_90.csv')

# %%
# Display the contents of each DataFrame
print("Contents of filtered_cp_above_90.csv:")
display(filtered_cp)

print("Contents of filtered_kd_above_90.csv:")
display(filtered_kd)

print("Contents of filtered_oe_above_90.csv:")
display(filtered_oe)

print("Contents of filtered_cc_above_90.csv:")
display(filtered_cc)
# Out:
# Contents of filtered_cp_above_90.csv:
#     Rank  Score Type             ID                     Name  \
# 0      5  99.88   cp  BRD-A02333338              cyclopamine
# 1     20  99.25   cp  BRD-K90543092           levonorgestrel
# 2     21  99.21   cp  BRD-K59456551             methotrexate
# 3     24  99.11   cp  BRD-K12994359               valdecoxib
# 4     32  98.78   cp  BRD-K11663430               pyroxamide
# 5     33  98.77   cp  BRD-K32311154               nifekalant
# 6     51  97.91   cp  BRD-K33226500                indinavir
# 7     59  97.39   cp  BRD-K41731458                triclosan
# 8     61  97.24   cp  BRD-K81709173              halcinonide
# 9     63  97.05   cp  BRD-A85587465               bemesetron
# 10    64  97.04   cp  BRD-A16311756              profenamine
# 11    72  96.62   cp  BRD-A28422058                 L-689560
# 12    76  96.42   cp  BRD-U73238814                 QL-XI-92
# 13    77  96.30   cp  BRD-A18202423                  CPCCOEt
# 14    81  95.85   cp  BRD-K49328571                dasatinib
# 15    84  95.71   cp  BRD-K20995441                 U-54494A
# 16    87  95.57   cp  BRD-K97863768            prothionamide
# 17    92  95.28   cp  BRD-K97330509  SRC-kinase-inhibitor-II
# 18    95  95.14   cp  BRD-K20285085             fostamatinib
# 19    98  94.92   cp  BRD-A41692738                  TGX-221
# 20    99  94.89   cp  BRD-K59419204                   AM-281
# 21   100  94.85   cp  BRD-K82823804                SA-792987
# 22   105  94.09   cp  BRD-K50891186                GR-103691
# 23   106  94.03   cp  BRD-K07888107                depudecin
# 24   107  94.02   cp  BRD-K78278890                   NM-PP1
# 25   111  93.90   cp  BRD-K34437622            BRD-K34437622
# 26   113  93.82   cp  BRD-K40758068                efavirenz
# 27   117  93.49   cp  BRD-A33711280                 metixene
# 28   120  93.28   cp  BRD-K63165456       norcyclobenzaprine
# 29   121  93.25   cp  BRD-K12120659                GR-144053
# 30   128  92.84   cp  BRD-K08115555       tyrphostin-AG-1288
# 31   129  92.78   cp  BRD-K89162000               tandutinib
# 32   133  92.62   cp  BRD-K51805276                  temefos
# 33   135  92.49   cp  BRD-K04976539           aminogenistein
# 34   136  92.34   cp  BRD-K92678294                 irilin-a
# 35   143  91.89   cp  BRD-K16508793                 diazepam
# 36   144  91.86   cp  BRD-K29673530                hypericin
# 37   145  91.82   cp  BRD-K17378184            prestwick-559
# 38   146  91.80   cp  BRD-A49370193               RO-60-0175
# 39   148  91.61   cp  BRD-K43880410             pregnenolone
# 40   151  91.30   cp  BRD-K01555864         dibenzoylmethane
# 41   157  91.10   cp  BRD-K17349619                  HLI-373
# 42   158  91.04   cp  BRD-K80431395              triciribine
# 43   159  90.98   cp  BRD-A34751532               homosalate
# 44   160  90.84   cp  BRD-K28863208               PNU-282987
# 45   161  90.81   cp  BRD-A53576514             orphenadrine
# 46   165  90.61   cp  BRD-K41337261                ZM-306416
# 47   166  90.54   cp  BRD-K70883034              nimetazepam
# 48   168  90.43   cp  BRD-K15262564                mupirocin
# 49   172  90.23   cp  BRD-K16478699                 PLX-4720
# 50   175  90.03   cp  BRD-K67847053                guanabenz
#
#                                           Description
# 0                      Smoothened receptor antagonist
# 1                           Estrogen receptor agonist
# 2                   Dihydrofolate reductase inhibitor
# 3                            Cyclooxygenase inhibitor
# 4                                      HDAC inhibitor
# 5                           Potassium channel blocker
# 6                              HIV protease inhibitor
# 7   Enoyl-[acyl-carrier-protein] reductase [NADH] ...
# 8                     Glucocorticoid receptor agonist
# 9                       Serotonin receptor antagonist
# 10                    Butyrylcholinesterase inhibitor
# 11                      Glutamate receptor antagonist
# 12                                     DDR1 inhibitor
# 13                      Glutamate receptor antagonist
# 14                           BCR-ABL kinase inhibitor
# 15                            Opioid receptor agonist
# 16  Mycobacterium tuberculosis enoyl-[acyl-carrier...
# 17                                      SRC inhibitor
# 18                                      SYK inhibitor
# 19                                     PI3K inhibitor
# 20                    Cannabinoid receptor antagonist
# 21                                      PKC inhibitor
# 22                       Dopamine receptor antagonist
# 23                                     HDAC inhibitor
# 24                            Mutant kinase inhibitor
# 25                     Thymidylate synthase inhibitor
# 26                             HIV protease inhibitor
# 27                  Acetylcholine receptor antagonist
# 28                        Adrenergic receptor agonist
# 29                                Integrin antagonist
# 30                           TNF production inhibitor
# 31                                     FLT3 inhibitor
# 32                           Cholinesterase inhibitor
# 33                                      SRC inhibitor
# 34                                         Isoflavone
# 35                    Benzodiazepine receptor agonist
# 36                          Tyrosine kinase inhibitor
# 37                          Dopamine receptor agonist
# 38                         Serotonin receptor agonist
# 39                       glutamate receptor modulator
# 40                                     Antineoplastic
# 41                                      MDM inhibitor
# 42                                      AKT inhibitor
# 43                                        HSP inducer
# 44                       Cholinergic receptor agonist
# 45                  Acetylcholine receptor antagonist
# 46                                      ABL inhibitor
# 47                              GABA receptor agonist
# 48                Isoleucyl-tRNA synthetase inhibitor
# 49                                      RAF inhibitor
# 50                        Adrenergic receptor agonist
# Contents of filtered_kd_above_90.csv:
#     Rank  Score Type            ID      Name  \
# 0      2  99.98   kd   CGS001-8848   TSC22D1
# 1      4  99.94   kd   CGS001-1196      CLK2
# 2      8  99.81   kd  CGS001-79109   MAPKAP1
# 3     11  99.74   kd  CGS001-29105  C16ORF80
# 4     14  99.70   kd  CGS001-10253     SPRY2
# ..   ...    ...  ...           ...       ...
# 57   139  92.21   kd   CGS001-9443      MED7
# 58   150  91.38   kd   CGS001-2058      EPRS
# 59   152  91.23   kd   CGS001-3660      IRF2
# 60   155  91.11   kd   CGS001-3460    IFNGR2
# 61   171  90.24   kd   CGS001-6617    SNAPC1
#
#                              Description
# 0                                      -
# 1                       CDC-like kinases
# 2                                      -
# 3                                      -
# 4                                      -
# ..                                   ...
# 57                                     -
# 58  Aminoacyl tRNA synthetases / Class I
# 59                                     -
# 60            Interferon receptor family
# 61                                     -
#
# [62 rows x 6 columns]
# Contents of filtered_oe_above_90.csv:
#     Rank  Score Type                  ID      Name  \
# 0      1  99.98   oe  ccsbBroad304_01966    RUVBL1
# 1      3  99.96   oe  ccsbBroad304_00841     IKBKB
# 2      6  99.82   oe  ccsbBroad304_07136     WNT9A
# 3      7  99.82   oe  ccsbBroad304_00101      RHOC
# 4      9  99.79   oe  ccsbBroad304_01623   SUPT4H1
# 5     10  99.77   oe  ccsbBroad304_00122    ATP1B1
# 6     12  99.72   oe  ccsbBroad304_06642      NIT1
# 7     13  99.71   oe  ccsbBroad304_07147      ZNF8
# 8     16  99.39   oe  ccsbBroad304_02322    ZNF263
# 9     23  99.16   oe  ccsbBroad304_00580      FLT1
# 10    26  99.07   oe  ccsbBroad304_07680      NEK6
# 11    28  98.98   oe  ccsbBroad304_07565      RBM6
# 12    30  98.97   oe  ccsbBroad304_04786     CANT1
# 13    31  98.97   oe  ccsbBroad304_05836     BIRC5
# 14    36  98.62   oe  ccsbBroad304_02057     P4HA2
# 15    38  98.56   oe  ccsbBroad304_04216      PBX4
# 16    39  98.48   oe  ccsbBroad304_03554     NAT10
# 17    45  98.25   oe  ccsbBroad304_00303      CHN1
# 18    50  98.01   oe  ccsbBroad304_04534      HN1L
# 19    56  97.63   oe  ccsbBroad304_09934       MKX
# 20    60  97.29   oe  ccsbBroad304_00469       DUT
# 21    65  97.01   oe  ccsbBroad304_01556   SMARCB1
# 22    67  96.96   oe  ccsbBroad304_09993     VN1R4
# 23    68  96.93   oe  ccsbBroad304_00049     ALDH2
# 24    71  96.64   oe  ccsbBroad304_08217    SCCPDH
# 25    82  95.79   oe  ccsbBroad304_08663     NMUR2
# 26    83  95.77   oe  ccsbBroad304_03696  C19ORF10
# 27    89  95.53   oe  ccsbBroad304_02772      ICMT
# 28    93  95.17   oe  ccsbBroad304_06908     S100B
# 29    96  94.98   oe  ccsbBroad304_05801   ALDH3A1
# 30    97  94.94   oe  ccsbBroad304_06916      SCP2
# 31   104  94.27   oe  ccsbBroad304_07761    CORO1A
# 32   110  93.90   oe  ccsbBroad304_02455     CREB3
# 33   112  93.87   oe  ccsbBroad304_09195      MCM8
# 34   115  93.68   oe  ccsbBroad304_07582      NET1
# 35   122  93.25   oe  ccsbBroad304_07651    HEXIM1
# 36   123  93.20   oe  ccsbBroad304_02683      COG2
# 37   125  93.05   oe  ccsbBroad304_05865    ATP1A3
# 38   127  92.98   oe  ccsbBroad304_03878     SENP2
# 39   130  92.74   oe  ccsbBroad304_01342     PTPN6
# 40   131  92.68   oe  ccsbBroad304_03647     CNDP2
# 41   132  92.66   oe  ccsbBroad304_02955     MYCBP
# 42   134  92.59   oe  ccsbBroad304_00792   HSD17B2
# 43   140  92.15   oe  ccsbBroad304_00020      ACY1
# 44   141  91.95   oe  ccsbBroad304_02373     SPRY2
# 45   142  91.89   oe  ccsbBroad304_02467    AGPAT1
# 46   147  91.72   oe  ccsbBroad304_04683    ZNF689
# 47   149  91.50   oe  ccsbBroad304_07267    PDLIM4
# 48   153  91.18   oe  ccsbBroad304_07411      LPXN
# 49   154  91.12   oe  ccsbBroad304_06720      PHYH
# 50   156  91.10   oe  ccsbBroad304_01141  PAFAH1B1
# 51   162  90.71   oe  ccsbBroad304_02979     RNF11
# 52   163  90.67   oe  ccsbBroad304_01065    NDUFA3
# 53   164  90.61   oe  ccsbBroad304_06038       CRK
# 54   167  90.47   oe  ccsbBroad304_00117      ATF4
# 55   169  90.38   oe  ccsbBroad304_04713     MAS1L
# 56   170  90.25   oe  ccsbBroad304_02416    TUBB4B
# 57   173  90.11   oe  ccsbBroad304_03161     FOXP3
# 58   174  90.04   oe  ccsbBroad304_01709     NR2C1
#
#                                           Description
# 0                                  ATPases / AAA-type
# 1                                          IKK family
# 2                Wingless-type MMTV integration sites
# 3                                                   -
# 4                                                   -
# 5                                    ATPases / P-type
# 6                                                   -
# 7                             Zinc fingers, C2H2-type
# 8                             Zinc fingers, C2H2-type
# 9   Type IV RTKs: VEGF (vascular endothelial growt...
# 10  NIMA (never in mitosis gene a)- related kinase...
# 11                          G patch domain containing
# 12                                                  -
# 13       Inhibitors of apoptosis (IAP) protein family
# 14                                                  -
# 15                            Homeoboxes / TALE class
# 16                                                  -
# 17                     Rho GTPase activating proteins
# 18                                                  -
# 19                            Homeoboxes / TALE class
# 20                                                  -
# 21                                                  -
# 22  GPCR / Unclassified : Vomeronasal receptors, t...
# 23                            Aldehyde dehydrogenases
# 24                                                  -
# 25            GPCR / Class A : Neuromedin U receptors
# 26                                                  -
# 27                                                  -
# 28                          EF-hand domain containing
# 29                            Aldehyde dehydrogenases
# 30                                                  -
# 31                                           Coronins
# 32                      basic leucine zipper proteins
# 33                                                  -
# 34            Rho guanine nucleotide exchange factors
# 35                                                  -
# 36             Components of oligomeric golgi complex
# 37                                   ATPases / P-type
# 38                                                  -
# 39                      Protein tyrosine phosphatases
# 40                              Carnosine dipeptidase
# 41                                                  -
# 42  Short chain dehydrogenase/reductase superfamil...
# 43                                                  -
# 44                                                  -
# 45      1-acylglycerol-3-phosphate O-acyltransferases
# 46                            Zinc fingers, C2H2-type
# 47                                                  -
# 48                                                  -
# 49                                                  -
# 50                        WD repeat domain containing
# 51                     RING-type (C3HC4) zinc fingers
# 52  Mitochondrial respiratory chain complex / Comp...
# 53                              SH2 domain containing
# 54                      basic leucine zipper proteins
# 55                           GPCR / Class A : Orphans
# 56                                                  -
# 57                                     Forkhead boxes
# 58                               Testicular receptors
# Contents of filtered_cc_above_90.csv:
#    Rank  Score Type  ID                                     Name Description
# 0    46  98.21   cc NaN              Aldehyde dehydrogenases LOF           -
# 1    80  96.15   cc NaN  Aminoacyl tRNA synthetases class II LOF           -
# 2    86  95.64   cc NaN                     Mediator complex LOF           -

# %% [markdown]
# ### Step 2: Generating Files for SwissADME
#
# - **Input:** `filtered_cp_above_90.csv`
#
# - **Output:**
#   - `compounds.csv`: A CSV file that includes compounds along with their names, PubChem CIDs, and SMILES notations.
#   - `molecules_for_adme.txt`: A text file containing SMILES notations formatted specifically for input into SwissADME.

# %%
import requests
import csv
import time

# Step 2: Generating Files for SwissADME
# Input: filtered_cp_above_90.csv
# Output: 'compounds.csv' and 'molecules_for_adme.txt'

df = pd.read_csv('filtered_cp_above_90.csv')
filtered_df = df[df['Score'] > 90]

# Extracting drug names list
drug_names = filtered_df['Name'].tolist()

def get_cid(name):
    """Fetch PubChem CID for the given compound name."""
    url = f'https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/{name}/cids/JSON'
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        cids = data.get('IdentifierList', {}).get('CID', [])
        return cids[0] if cids else None
    return None

def get_smiles(cid):
    """Fetch SMILES notation for the given CID."""
    url = f'https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/{cid}/property/ConnectivitySMILES/JSON'
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        props = data.get('PropertyTable', {}).get('Properties', [])
        return props[0]['ConnectivitySMILES'] if props and 'ConnectivitySMILES' in props[0] else None
    return None

output = []
output_for_adme = []

for name in drug_names:
    cid = get_cid(name)
    if cid:
        smiles = get_smiles(cid)
        if smiles:
            output.append([name, cid, smiles])
            output_for_adme.append(f"{smiles} {name}")
            print(f"✅ {name}: CID={cid}, SMILES found -> {smiles}")
        else:
            print(f"❌ {name}: SMILES not found for CID {cid}")
    else:
        print(f"❌ {name}: CID not found")
    time.sleep(0.2)  # Prevent request rate limits

# Save CSV file with compounds having SMILES
with open('compounds.csv', 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['Compound Name', 'CID', 'SMILES Notation'])
    writer.writerows(output)

print("\nCSV file 'compounds.csv' created successfully with compounds that have SMILES.")

# Save text file formatted for SwissADME input
with open('molecules_for_adme.txt', 'w', encoding='utf-8') as f:
    for line in output_for_adme:
        f.write(line + "\n")

print("Text file 'molecules_for_adme.txt' created successfully for SwissADME input.")
# Out:
# ✅ cyclopamine: CID=442972, SMILES found -> CC1CC2C(C(C3(O2)CCC4C5CC=C6CC(CCC6(C5CC4=C3C)C)O)C)NC1
# ✅ levonorgestrel: CID=13109, SMILES found -> CCC12CCC3C(C1CCC2(C#C)O)CCC4=CC(=O)CCC34
# ✅ methotrexate: CID=126941, SMILES found -> CN(CC1=CN=C2C(=N1)C(=NC(=N2)N)N)C3=CC=C(C=C3)C(=O)NC(CCC(=O)O)C(=O)O
# ✅ valdecoxib: CID=119607, SMILES found -> CC1=C(C(=NO1)C2=CC=CC=C2)C3=CC=C(C=C3)S(=O)(=O)N
# ✅ pyroxamide: CID=4996, SMILES found -> C1=CC(=CN=C1)NC(=O)CCCCCCC(=O)NO
# ✅ nifekalant: CID=4486, SMILES found -> CN1C(=CC(=O)N(C1=O)C)NCCN(CCCC2=CC=C(C=C2)[N+](=O)[O-])CCO
# ✅ indinavir: CID=5362440, SMILES found -> CC(C)(C)NC(=O)C1CN(CCN1CC(CC(CC2=CC=CC=C2)C(=O)NC3C(CC4=CC=CC=C34)O)O)CC5=CN=CC=C5
# ✅ triclosan: CID=5564, SMILES found -> C1=CC(=C(C=C1Cl)O)OC2=C(C=C(C=C2)Cl)Cl
# ✅ halcinonide: CID=443943, SMILES found -> CC1(OC2CC3C4CCC5=CC(=O)CCC5(C4(C(CC3(C2(O1)C(=O)CCl)C)O)F)C)C
# ✅ bemesetron: CID=671690, SMILES found -> CN1C2CCC1CC(C2)OC(=O)C3=CC(=CC(=C3)Cl)Cl
# ✅ profenamine: CID=3290, SMILES found -> CCN(CC)C(C)CN1C2=CC=CC=C2SC3=CC=CC=C31
# ✅ L-689560: CID=121918, SMILES found -> C1C(C2=C(C=C(C=C2Cl)Cl)NC1C(=O)O)NC(=O)NC3=CC=CC=C3
# ✅ QL-XI-92: CID=73265214, SMILES found -> CC1=C(C=C(C=C1)C(=O)NC2=CC(=CC(=C2)NC(=O)C=C)C(F)(F)F)NC(=O)C3=CC=NO3
# ✅ CPCCOEt: CID=6278000, SMILES found -> CCOC(=O)C12CC1C(=NO)C3=CC=CC=C3O2
# ✅ dasatinib: CID=3062316, SMILES found -> CC1=C(C(=CC=C1)Cl)NC(=O)C2=CN=C(S2)NC3=CC(=NC(=N3)C)N4CCN(CC4)CCO
# ✅ U-54494A: CID=122015, SMILES found -> CN(C1CCCCC1N2CCCC2)C(=O)C3=CC(=C(C=C3)Cl)Cl
# ✅ prothionamide: CID=666418, SMILES found -> CCCC1=NC=CC(=C1)C(=S)N
# ❌ SRC-kinase-inhibitor-II: CID not found
# ✅ fostamatinib: CID=11671467, SMILES found -> CC1(C(=O)N(C2=C(O1)C=CC(=N2)NC3=NC(=NC=C3F)NC4=CC(=C(C(=C4)OC)OC)OC)COP(=O)(O)O)C
# ✅ TGX-221: CID=9907093, SMILES found -> CC1=CN2C(=O)C=C(N=C2C(=C1)C(C)NC3=CC=CC=C3)N4CCOCC4
# ✅ AM-281: CID=4302962, SMILES found -> CC1=C(N(N=C1C(=O)NN2CCOCC2)C3=C(C=C(C=C3)Cl)Cl)C4=CC=C(C=C4)I
# ❌ SA-792987: CID not found
# ✅ GR-103691: CID=4302960, SMILES found -> CC(=O)C1=CC=C(C=C1)C2=CC=C(C=C2)C(=O)NCCCCN3CCN(CC3)C4=CC=CC=C4OC
# ✅ depudecin: CID=16219259, SMILES found -> CC(C1C(O1)C=CC2C(O2)C(C=C)O)O
# ✅ NM-PP1: CID=5154691, SMILES found -> CC(C)(C)N1C2=NC=NC(=C2C(=N1)CC3=CC=CC4=CC=CC=C43)N
# ❌ BRD-K34437622: CID not found
# ✅ efavirenz: CID=64139, SMILES found -> C1CC1C#CC2(C3=C(C=CC(=C3)Cl)NC(=O)O2)C(F)(F)F
# ✅ metixene: CID=4167, SMILES found -> CN1CCCC(C1)CC2C3=CC=CC=C3SC4=CC=CC=C24
# ✅ norcyclobenzaprine: CID=9918, SMILES found -> CNCCC=C1C2=CC=CC=C2C=CC3=CC=CC=C31
# ✅ GR-144053: CID=173614, SMILES found -> C1CN(CCC1N2CCN(CC2)C3=CC=C(C=C3)C(=N)N)CC(=O)O
# ❌ tyrphostin-AG-1288: CID not found
# ✅ tandutinib: CID=3038522, SMILES found -> CC(C)OC1=CC=C(C=C1)NC(=O)N2CCN(CC2)C3=NC=NC4=CC(=C(C=C43)OC)OCCCN5CCCCC5
# ✅ temefos: CID=5392, SMILES found -> COP(=S)(OC)OC1=CC=C(C=C1)SC2=CC=C(C=C2)OP(=S)(OC)OC
# ✅ aminogenistein: CID=125519, SMILES found -> C1=CC(=CC=C1C2=CC(=O)C3=C(O2)C=CC(=C3)O)N
# ✅ irilin-a: CID=5491550, SMILES found -> COC1=C(C(=C2C(=C1)OC=C(C2=O)C3=CC=CC=C3O)O)OC
# ✅ diazepam: CID=3016, SMILES found -> CN1C(=O)CN=C(C2=C1C=CC(=C2)Cl)C3=CC=CC=C3
# ✅ hypericin: CID=3663, SMILES found -> CC1=CC(=O)C2=C(C3=C(C=C(C4=C3C5=C2C1=C6C(=CC(=O)C7=C(C8=C(C=C(C4=C8C5=C67)O)O)O)C)O)O)O
# ❌ prestwick-559: CID not found
# ✅ RO-60-0175: CID=3045227, SMILES found -> CC(CN1C=CC2=CC(=C(C=C21)Cl)F)N
# ✅ pregnenolone: CID=8955, SMILES found -> CC(=O)C1CCC2C1(CCC3C2CC=C4C3(CCC(C4)O)C)C
# ✅ dibenzoylmethane: CID=8433, SMILES found -> C1=CC=C(C=C1)C(=O)CC(=O)C2=CC=CC=C2
# ❌ HLI-373: CID not found
# ✅ triciribine: CID=65399, SMILES found -> CN1C2=NC=NC3=C2C(=CN3C4C(C(C(O4)CO)O)O)C(=N1)N
# ✅ homosalate: CID=8362, SMILES found -> CC1CC(CC(C1)(C)C)OC(=O)C2=CC=CC=C2O
# ✅ PNU-282987: CID=11243536, SMILES found -> C1CN2CCC1C(C2)NC(=O)C3=CC=C(C=C3)Cl.Cl
# ✅ orphenadrine: CID=4601, SMILES found -> CC1=CC=CC=C1C(C2=CC=CC=C2)OCCN(C)C
# ✅ ZM-306416: CID=5329006, SMILES found -> COC1=C(C=C2C(=C1)C(=NC=N2)NC3=C(C=C(C=C3)Cl)F)OC
# ✅ nimetazepam: CID=4496, SMILES found -> CN1C(=O)CN=C(C2=C1C=CC(=C2)[N+](=O)[O-])C3=CC=CC=C3
# ✅ mupirocin: CID=446596, SMILES found -> CC(C1C(O1)CC2COC(C(C2O)O)CC(=CC(=O)OCCCCCCCCC(=O)O)C)C(C)O
# ✅ PLX-4720: CID=24180719, SMILES found -> CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=C2C=C(C=N3)Cl)F
# ✅ guanabenz: CID=5702063, SMILES found -> C1=CC(=C(C(=C1)Cl)C=NN=C(N)N)Cl
#
# CSV file 'compounds.csv' created successfully with compounds that have SMILES.
# Text file 'molecules_for_adme.txt' created successfully for SwissADME input.

# %%
# Load and display CSV files
compounds = pd.read_csv('compounds.csv')

# Display the contents of each DataFrame
print("Contents of compounds.csv:")
display(compounds)
# Out:
# Contents of compounds.csv:
#          Compound Name       CID  \
# 0          cyclopamine    442972
# 1       levonorgestrel     13109
# 2         methotrexate    126941
# 3           valdecoxib    119607
# 4           pyroxamide      4996
# 5           nifekalant      4486
# 6            indinavir   5362440
# 7            triclosan      5564
# 8          halcinonide    443943
# 9           bemesetron    671690
# 10         profenamine      3290
# 11            L-689560    121918
# 12            QL-XI-92  73265214
# 13             CPCCOEt   6278000
# 14           dasatinib   3062316
# 15            U-54494A    122015
# 16       prothionamide    666418
# 17        fostamatinib  11671467
# 18             TGX-221   9907093
# 19              AM-281   4302962
# 20           GR-103691   4302960
# 21           depudecin  16219259
# 22              NM-PP1   5154691
# 23           efavirenz     64139
# 24            metixene      4167
# 25  norcyclobenzaprine      9918
# 26           GR-144053    173614
# 27          tandutinib   3038522
# 28             temefos      5392
# 29      aminogenistein    125519
# 30            irilin-a   5491550
# 31            diazepam      3016
# 32           hypericin      3663
# 33          RO-60-0175   3045227
# 34        pregnenolone      8955
# 35    dibenzoylmethane      8433
# 36         triciribine     65399
# 37          homosalate      8362
# 38          PNU-282987  11243536
# 39        orphenadrine      4601
# 40           ZM-306416   5329006
# 41         nimetazepam      4496
# 42           mupirocin    446596
# 43            PLX-4720  24180719
# 44           guanabenz   5702063
#
#                                       SMILES Notation
# 0   CC1CC2C(C(C3(O2)CCC4C5CC=C6CC(CCC6(C5CC4=C3C)C...
# 1            CCC12CCC3C(C1CCC2(C#C)O)CCC4=CC(=O)CCC34
# 2   CN(CC1=CN=C2C(=N1)C(=NC(=N2)N)N)C3=CC=C(C=C3)C...
# 3    CC1=C(C(=NO1)C2=CC=CC=C2)C3=CC=C(C=C3)S(=O)(=O)N
# 4                    C1=CC(=CN=C1)NC(=O)CCCCCCC(=O)NO
# 5   CN1C(=CC(=O)N(C1=O)C)NCCN(CCCC2=CC=C(C=C2)[N+]...
# 6   CC(C)(C)NC(=O)C1CN(CCN1CC(CC(CC2=CC=CC=C2)C(=O...
# 7              C1=CC(=C(C=C1Cl)O)OC2=C(C=C(C=C2)Cl)Cl
# 8   CC1(OC2CC3C4CCC5=CC(=O)CCC5(C4(C(CC3(C2(O1)C(=...
# 9            CN1C2CCC1CC(C2)OC(=O)C3=CC(=CC(=C3)Cl)Cl
# 10             CCN(CC)C(C)CN1C2=CC=CC=C2SC3=CC=CC=C31
# 11  C1C(C2=C(C=C(C=C2Cl)Cl)NC1C(=O)O)NC(=O)NC3=CC=...
# 12  CC1=C(C=C(C=C1)C(=O)NC2=CC(=CC(=C2)NC(=O)C=C)C...
# 13                  CCOC(=O)C12CC1C(=NO)C3=CC=CC=C3O2
# 14  CC1=C(C(=CC=C1)Cl)NC(=O)C2=CN=C(S2)NC3=CC(=NC(...
# 15        CN(C1CCCCC1N2CCCC2)C(=O)C3=CC(=C(C=C3)Cl)Cl
# 16                             CCCC1=NC=CC(=C1)C(=S)N
# 17  CC1(C(=O)N(C2=C(O1)C=CC(=N2)NC3=NC(=NC=C3F)NC4...
# 18  CC1=CN2C(=O)C=C(N=C2C(=C1)C(C)NC3=CC=CC=C3)N4C...
# 19  CC1=C(N(N=C1C(=O)NN2CCOCC2)C3=C(C=C(C=C3)Cl)Cl...
# 20  CC(=O)C1=CC=C(C=C1)C2=CC=C(C=C2)C(=O)NCCCCN3CC...
# 21                      CC(C1C(O1)C=CC2C(O2)C(C=C)O)O
# 22  CC(C)(C)N1C2=NC=NC(=C2C(=N1)CC3=CC=CC4=CC=CC=C...
# 23      C1CC1C#CC2(C3=C(C=CC(=C3)Cl)NC(=O)O2)C(F)(F)F
# 24             CN1CCCC(C1)CC2C3=CC=CC=C3SC4=CC=CC=C24
# 25                 CNCCC=C1C2=CC=CC=C2C=CC3=CC=CC=C31
# 26     C1CN(CCC1N2CCN(CC2)C3=CC=C(C=C3)C(=N)N)CC(=O)O
# 27  CC(C)OC1=CC=C(C=C1)NC(=O)N2CCN(CC2)C3=NC=NC4=C...
# 28  COP(=S)(OC)OC1=CC=C(C=C1)SC2=CC=C(C=C2)OP(=S)(...
# 29          C1=CC(=CC=C1C2=CC(=O)C3=C(O2)C=CC(=C3)O)N
# 30      COC1=C(C(=C2C(=C1)OC=C(C2=O)C3=CC=CC=C3O)O)OC
# 31          CN1C(=O)CN=C(C2=C1C=CC(=C2)Cl)C3=CC=CC=C3
# 32  CC1=CC(=O)C2=C(C3=C(C=C(C4=C3C5=C2C1=C6C(=CC(=...
# 33                     CC(CN1C=CC2=CC(=C(C=C21)Cl)F)N
# 34          CC(=O)C1CCC2C1(CCC3C2CC=C4C3(CCC(C4)O)C)C
# 35                C1=CC=C(C=C1)C(=O)CC(=O)C2=CC=CC=C2
# 36     CN1C2=NC=NC3=C2C(=CN3C4C(C(C(O4)CO)O)O)C(=N1)N
# 37                CC1CC(CC(C1)(C)C)OC(=O)C2=CC=CC=C2O
# 38             C1CN2CCC1C(C2)NC(=O)C3=CC=C(C=C3)Cl.Cl
# 39                 CC1=CC=CC=C1C(C2=CC=CC=C2)OCCN(C)C
# 40   COC1=C(C=C2C(=C1)C(=NC=N2)NC3=C(C=C(C=C3)Cl)F)OC
# 41  CN1C(=O)CN=C(C2=C1C=CC(=C2)[N+](=O)[O-])C3=CC=...
# 42  CC(C1C(O1)CC2COC(C(C2O)O)CC(=CC(=O)OCCCCCCCCC(...
# 43  CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=C2C...
# 44                    C1=CC(=C(C(=C1)Cl)C=NN=C(N)N)Cl

# %%
# Load and display the text file
with open('molecules_for_adme.txt', 'r') as file:
    molecules_for_adme_content = file.read()

print("Contents of molecules_for_adme.txt:")
print(molecules_for_adme_content)
# Out:
# Contents of molecules_for_adme.txt:
# CC1CC2C(C(C3(O2)CCC4C5CC=C6CC(CCC6(C5CC4=C3C)C)O)C)NC1 cyclopamine
# CCC12CCC3C(C1CCC2(C#C)O)CCC4=CC(=O)CCC34 levonorgestrel
# CN(CC1=CN=C2C(=N1)C(=NC(=N2)N)N)C3=CC=C(C=C3)C(=O)NC(CCC(=O)O)C(=O)O methotrexate
# CC1=C(C(=NO1)C2=CC=CC=C2)C3=CC=C(C=C3)S(=O)(=O)N valdecoxib
# C1=CC(=CN=C1)NC(=O)CCCCCCC(=O)NO pyroxamide
# CN1C(=CC(=O)N(C1=O)C)NCCN(CCCC2=CC=C(C=C2)[N+](=O)[O-])CCO nifekalant
# CC(C)(C)NC(=O)C1CN(CCN1CC(CC(CC2=CC=CC=C2)C(=O)NC3C(CC4=CC=CC=C34)O)O)CC5=CN=CC=C5 indinavir
# C1=CC(=C(C=C1Cl)O)OC2=C(C=C(C=C2)Cl)Cl triclosan
# CC1(OC2CC3C4CCC5=CC(=O)CCC5(C4(C(CC3(C2(O1)C(=O)CCl)C)O)F)C)C halcinonide
# CN1C2CCC1CC(C2)OC(=O)C3=CC(=CC(=C3)Cl)Cl bemesetron
# CCN(CC)C(C)CN1C2=CC=CC=C2SC3=CC=CC=C31 profenamine
# C1C(C2=C(C=C(C=C2Cl)Cl)NC1C(=O)O)NC(=O)NC3=CC=CC=C3 L-689560
# CC1=C(C=C(C=C1)C(=O)NC2=CC(=CC(=C2)NC(=O)C=C)C(F)(F)F)NC(=O)C3=CC=NO3 QL-XI-92
# CCOC(=O)C12CC1C(=NO)C3=CC=CC=C3O2 CPCCOEt
# CC1=C(C(=CC=C1)Cl)NC(=O)C2=CN=C(S2)NC3=CC(=NC(=N3)C)N4CCN(CC4)CCO dasatinib
# CN(C1CCCCC1N2CCCC2)C(=O)C3=CC(=C(C=C3)Cl)Cl U-54494A
# CCCC1=NC=CC(=C1)C(=S)N prothionamide
# CC1(C(=O)N(C2=C(O1)C=CC(=N2)NC3=NC(=NC=C3F)NC4=CC(=C(C(=C4)OC)OC)OC)COP(=O)(O)O)C fostamatinib
# CC1=CN2C(=O)C=C(N=C2C(=C1)C(C)NC3=CC=CC=C3)N4CCOCC4 TGX-221
# CC1=C(N(N=C1C(=O)NN2CCOCC2)C3=C(C=C(C=C3)Cl)Cl)C4=CC=C(C=C4)I AM-281
# CC(=O)C1=CC=C(C=C1)C2=CC=C(C=C2)C(=O)NCCCCN3CCN(CC3)C4=CC=CC=C4OC GR-103691
# CC(C1C(O1)C=CC2C(O2)C(C=C)O)O depudecin
# CC(C)(C)N1C2=NC=NC(=C2C(=N1)CC3=CC=CC4=CC=CC=C43)N NM-PP1
# C1CC1C#CC2(C3=C(C=CC(=C3)Cl)NC(=O)O2)C(F)(F)F efavirenz
# CN1CCCC(C1)CC2C3=CC=CC=C3SC4=CC=CC=C24 metixene
# CNCCC=C1C2=CC=CC=C2C=CC3=CC=CC=C31 norcyclobenzaprine
# C1CN(CCC1N2CCN(CC2)C3=CC=C(C=C3)C(=N)N)CC(=O)O GR-144053
# CC(C)OC1=CC=C(C=C1)NC(=O)N2CCN(CC2)C3=NC=NC4=CC(=C(C=C43)OC)OCCCN5CCCCC5 tandutinib
# COP(=S)(OC)OC1=CC=C(C=C1)SC2=CC=C(C=C2)OP(=S)(OC)OC temefos
# C1=CC(=CC=C1C2=CC(=O)C3=C(O2)C=CC(=C3)O)N aminogenistein
# COC1=C(C(=C2C(=C1)OC=C(C2=O)C3=CC=CC=C3O)O)OC irilin-a
# CN1C(=O)CN=C(C2=C1C=CC(=C2)Cl)C3=CC=CC=C3 diazepam
# CC1=CC(=O)C2=C(C3=C(C=C(C4=C3C5=C2C1=C6C(=CC(=O)C7=C(C8=C(C=C(C4=C8C5=C67)O)O)O)C)O)O)O hypericin
# CC(CN1C=CC2=CC(=C(C=C21)Cl)F)N RO-60-0175
# CC(=O)C1CCC2C1(CCC3C2CC=C4C3(CCC(C4)O)C)C pregnenolone
# C1=CC=C(C=C1)C(=O)CC(=O)C2=CC=CC=C2 dibenzoylmethane
# CN1C2=NC=NC3=C2C(=CN3C4C(C(C(O4)CO)O)O)C(=N1)N triciribine
# CC1CC(CC(C1)(C)C)OC(=O)C2=CC=CC=C2O homosalate
# C1CN2CCC1C(C2)NC(=O)C3=CC=C(C=C3)Cl.Cl PNU-282987
# CC1=CC=CC=C1C(C2=CC=CC=C2)OCCN(C)C orphenadrine
# COC1=C(C=C2C(=C1)C(=NC=N2)NC3=C(C=C(C=C3)Cl)F)OC ZM-306416
# CN1C(=O)CN=C(C2=C1C=CC(=C2)[N+](=O)[O-])C3=CC=CC=C3 nimetazepam
# CC(C1C(O1)CC2COC(C(C2O)O)CC(=CC(=O)OCCCCCCCCC(=O)O)C)C(C)O mupirocin
# CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=C2C=C(C=N3)Cl)F PLX-4720
# C1=CC(=C(C(=C1)Cl)C=NN=C(N)N)Cl guanabenz

# %% [markdown]
# ### Step-by-Step Explanation
#
# #### Step 1: Filtering Data
# 1. **Read the Input File:** Load the data from `export.csv`.
# 2. **Filter Rows:** Filter the rows based on the drug type (`cp`, `kd`, `oe`, `cc`) and scores above 90.
# 3. **Save Filtered Data:** Save the filtered data into separate CSV files:
#    - `filtered_cp_above_90.csv` for drug type `cp`.
#    - `filtered_kd_above_90.csv` for drug type `kd`.
#    - `filtered_oe_above_90.csv` for drug type `oe`.
#    - `filtered_cc_above_90.csv` for drug type `cc`.
#
# #### Step 2: Fetching CID and SMILES
# 1. **Read the Filtered File:** Load the filtered data from `filtered_cp_above_90.csv`.
# 2. **Extract Drug Names:** Create a list of drug names from the filtered data.
# 3. **Fetch CID and SMILES:**
#    - Use the PubChem API to obtain the CID (unique identifier) for each drug name.
#    - Use the CID to retrieve the SMILES (chemical structure representation) from PubChem.
# 4. **Save Output Files:**
#    - `compounds.csv`: Contains drug name, CID, and SMILES notation.
#    - `molecules_for_adme.txt`: Contains SMILES formatted for input into SwissADME.
#
# #### Imported Libraries
# - **pandas:** For reading and processing CSV files.
# - **requests:** For making HTTP requests to the PubChem API.
# - **csv:** For writing CSV files.
# - **time:** For adding delays between API requests to avoid rate limiting.

# %% [markdown]
# ### Conclusion
#
# The data processing workflow for drug repurposing has been successfully implemented in two key steps. Initially, the data was filtered to identify relevant compounds based on specific criteria, such as drug type and score thresholds. This allowed for the creation of targeted CSV files that facilitate further analysis.
#
# In the second step, the integration with the PubChem API enabled the retrieval of essential chemical information, including PubChem CIDs and SMILES notations, for the identified compounds. This data is crucial for conducting in-depth analyses and simulations in platforms like SwissADME, which assess the pharmacokinetic properties of compounds.
#
# Overall, this systematic approach not only streamlines the data processing but also enhances the quality of information available for drug repurposing efforts, ultimately contributing to more efficient drug discovery and development processes.
